# %%
import os, sys, wave, struct

import numpy as np
import pyaudio
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sounddevice as sd

from copy import deepcopy
from math import ceil, exp, atan, pi, cos, sin
import mdctn
from scipy.io.wavfile import write
#import scipy.io.wavfile
from scipy.linalg import hankel
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

import pylab as p
#import matplotlib.axes3d as p3
import mpl_toolkits.mplot3d.axes3d as p3

from scipy.signal import periodogram

# %% [markdown]
# # Useful functions

# %%
def load_sound(file):
    return wave.open(file, 'rb')

def play_sound(file, chunk = 1024):
    """
    Script from PyAudio doc
    """
    wf = load_sound(file)
    p = pyaudio.PyAudio()
    stream = p.open(format=p.get_format_from_width(wf.getsampwidth()),
                    channels=wf.getnchannels(),
                    rate=wf.getframerate(),
                    output=True)
    data = wf.readframes(chunk)

    while data:
        stream.write(data)
        data = wf.readframes(chunk )

    stream.stop_stream()
    stream.close()
    p.terminate()
    
def plot_sound(data, times,xlim1,xlim2,name='default_name', save=False,w=20,h=10, lw = 3):
    plt.figure(figsize=(w, h))
    plt.plot(times,x.reshape(len_x))
    plt.xlim(xlim1,xlim2)
    plt.xlabel('time (s)')
    plt.ylabel('amplitude')
    if save:
        plt.savefig(name+'.png', dpi=100)
    plt.show()
    
def read_values(filename):
    wave_file = wave.open(filename, 'r')
    nframes = wave_file.getnframes()
    nchannels = wave_file.getnchannels()
    sampling_frequency = wave_file.getframerate()
    T = nframes / float(sampling_frequency)
    read_frames = wave_file.readframes(nframes)
    wave_file.close()
    data = struct.unpack("%dh" %  nchannels*nframes, read_frames)
    
    data_per_channel = [data[offset::nchannels] for offset in range(nchannels)]
    return T, np.array(data_per_channel), nframes, nchannels, sampling_frequency

# %%
def Synthesis(N,delta,f,a,phi,RSB=False):
    t = range(N)
    logz = delta + 1j*2*np.pi*f
    alpha = a*np.exp(1j*phi)
    x = np.sum(np.outer(alpha, np.ones(N))*np.exp(np.outer(logz,t)), axis=0)
    if RSB == False: 
        s = x
    else: 
        Ex = np.real(np.sum(np.abs(x)**2))/N
        b = np.random.normal(size=N) + 1j*np.random.normal(size=N)
        Eb = np.real(np.sum(np.abs(b)**2))/N
        b = b*np.sqrt(Ex/Eb)*10**(-RSB/20)
        s = x+b    
    return s

# %% [markdown]
# # Open audio file

# %%
wavefile = load_sound('clocheB.WAV')
print(wavefile.getparams())
# Out:
# _wave_params(nchannels=1, sampwidth=2, framerate=8000, nframes=99414, comptype='NONE', compname='not compressed')

# %%
play = False
if play :
    play_sound('clocheB.WAV')

# %%
T, data, nframes, nchannels, sampling_frequency = read_values('clocheA.WAV')
Fs = int(wavefile.getframerate())
x = np.array(data)
num_samples = int(wavefile.getnframes())

# %%
len_x = x.shape[1]
timestep = 1/(float(Fs))
times = np.arange(len_x)*timestep # int(len_x/6)
plot_sound(x.reshape(len_x), times,0,12,w=10,h=7)

# %%
write('new_bell.wav', Fs, np.array(x.reshape(len_x), dtype=np.int16)) # to write a new wave file

# %% [markdown]
# # 3 Signal synthétique

# %%
N = 63
f0 = 1/4
f1 = f0 + 1/N
f = np.array([f0, f1])
a = np.array([1, 10])
delta = np.array([0, -0.05])
phi = np.array([np.pi/2, -np.pi/2])

x = Synthesis(N, delta, f, a, phi)

# %% [markdown]
# ## 3.1 Analyse spectrale par transformation de Fourier

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 7))

# without zero-padding

N_fft = N

X_fft = np.fft.fft(x, n=N_fft)
freqs = np.fft.fftfreq(N_fft)

ax[0].plot(freqs, np.abs(X_fft))
ax[0].set_ylabel('Magnitude')
ax[0].set_title('Without zero-padding')

# with zero-padding

N_fft = 1024 # >N

X_fft = np.fft.fft(x, n=N_fft)
freqs = np.fft.fftfreq(N_fft)

ax[1].plot(freqs, np.abs(X_fft))
ax[1].set_xlabel('Frequency (Hz)')
ax[1].set_ylabel('Magnitude')
ax[1].set_title('With zero-padding')

plt.show()

# %% [markdown]
# ## 3.2 Méthodes à haute résolution

# %%
n = 32
K=2

# %% [markdown]
# 1. Calcul de la matrice de corrélation

# %%
# get hankel matrix of x: X
def get_hankel(x, n):
    X = hankel(x[:n], x[n-1:])
    return X

# get correlation of X: R_xx
def get_correlation(X, n):
    l = x.shape[0] - n + 1
    R_xx = X @ X.transpose().conj() / l
    return R_xx

# %% [markdown]
# 2. Estimation de l’espace signal

# %%
# get signal space W and Wt
def get_W(R_xx, K):
    U, _, Vh = np.linalg.svd(R_xx)
    W = U[:, :K]
    Wt = Vh[:, K:]
    return W, Wt

# %% [markdown]
# ### 3.2.1 Algorithme ESPRIT
#
# 3. Estimation des fréquences et des facteurs d’amortissement

# %%
def get_delta_f(W):
    # get W_up and W_down from W
    W_up = W[1:, :]
    W_down = W[:-1, :]

    # compute Phi
    Phi = np.linalg.pinv(W_down) @ W_up

    # get eigenvalues of Phi
    zk,_ = np.linalg.eig(Phi)

    delta_k = np.log(np.abs(zk))
    f_k = np.angle(zk) / (2 * np.pi)

    return delta_k, f_k

def ESPRIT(x, n, K, threshold=None):
    X = get_hankel(x, n)
    R_xx = get_correlation(X, n)
    W, Wt = get_W(R_xx, K)
    delta_k, f_k = get_delta_f(W)
    # for the case of delta > 0, use a threshold instead
    if threshold != None:
        delta_k = [min(delta, threshold) for delta in delta_k]
    return delta_k, f_k

# %% [markdown]
# 4. Estimation des amplitudes et des phases

# %%
def LeastSquares(x, delta, f):
    ln_z = delta + 2j * np.pi * f
    V = np.exp(np.outer(np.arange(x.shape[0]), ln_z))
    alpha = np.linalg.pinv(V) @ x.transpose()
    a = np.abs(alpha)
    phi = np.angle(alpha)
    return a, phi

# %% [markdown]
# 5. Application aux signaux synthétiques

# %%
delta, f = ESPRIT(x, n, K)
est_a, est_phi = LeastSquares(x, delta, f)

print(f'true a: {a}\t estimated a: {est_a}')
print(f'true phi: {phi}\t estimated phi: {est_phi}')
# Out:
# true a: [ 1 10]	 estimated a: [10.  1.]
# true phi: [ 1.57079633 -1.57079633]	 estimated phi: [-1.57079633  1.57079633]

# %% [markdown]
# ### 3.2.2 Méthode MUSIC
#
# 6. Affichage du pseudo-spectre MUSIC

# %%
def MUSIC(x, n, K, delta_grid, f_grid):
    X = get_hankel(x, n)
    R_xx = get_correlation(X, n)
    _, Wt = get_W(R_xx, K)
    v_n_z = np.vander((np.exp(delta_grid + 2j * np.pi * f_grid)).flatten(), n, increasing=True).T 
    product = np.dot(Wt.conj().transpose(), v_n_z)
    norm_square = np.linalg.norm(product, axis=0) ** 2
    P = 1 / norm_square
    P = P.reshape(delta_grid.shape)
    return P

delta_vals = np.linspace(-0.1, 0.1, 512)
f_vals = np.linspace(0, 1, 512)
delta_grid, f_grid = np.meshgrid(delta_vals, f_vals)

P = MUSIC(x, n, K, delta_grid, f_grid)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(delta_grid, f_grid, P, cmap=cm.coolwarm)
ax.set_xlabel('delta')
ax.set_ylabel('f')
ax.set_zlabel('P')
ax.set_title('MUSIC spectrum')
plt.show()

# %% [markdown]
# # 4 Signaux audio

# %%
T, data, nframes, nchannels, sampling_frequency = read_values('clocheA.WAV')
Fs = int(wavefile.getframerate())
x = np.array(data)
num_samples = int(wavefile.getnframes())

# %% [markdown]
# ## 4.1 Analyse spectrale par transformation de Fourier

# %%
# periodogram
x = x.flatten()
freqs, P_xx = periodogram(x, Fs)
P_xx = P_xx.flatten()

# values in Introduction
alpha = np.array([0.5, 1, 1.2, 1.5, 2, 2.5, 2.6, 2.7, 3, 3.3, 3.7, 4.2, 4.5, 5, 5.9])
f_p = freqs[P_xx == max(P_xx)]
f_n = f_p * alpha
P_n = np.interp(f_n, freqs, P_xx)

# plot
fig, ax = plt.subplots(figsize=(10, 7))
ax.semilogy(freqs, np.abs(P_xx), zorder=1)
ax.vlines(f_n, ymin=min(np.abs(P_xx)), ymax=P_n, color='red', linestyles='dashed', zorder=2)
ax.scatter(f_n, P_n, color='red', marker='x', zorder=3)
ax.set_xlabel('Frequency (Hz)')
ax.set_title('Periodogram')
plt.show()

# %% [markdown]
# ## 4.2 Méthode à haute résolution

# %%
K = 54
n = 512
l = 2 * n
N = n + l - 1

start = 10000

sig = x[start: start + N]
sig_delta, sig_f = ESPRIT(sig, n, K, threshold=-1e-5)
sig_a, sig_phi = LeastSquares(sig, sig_delta, sig_f)

delta_vals = np.linspace(-0.1, 0.1, 256)
f_vals = np.linspace(0, 1, 256)
delta_grid, f_grid = np.meshgrid(delta_vals, f_vals)

P = MUSIC(sig, n, K, delta_grid, f_grid)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(delta_grid, f_grid, P, cmap=cm.coolwarm)
ax.set_xlabel('delta')
ax.set_ylabel('f')
ax.set_zlabel('P')
ax.set_title('MUSIC spectrum')
plt.show()

# %%
sig_synthesis = Synthesis(len(x), sig_delta, sig_f, sig_a, sig_phi)
sig_synthesis = np.real(sig_synthesis)
sig_synthesis = (sig_synthesis - min(sig_synthesis)) / (max(sig_synthesis) - min(sig_synthesis))
sig_synthesis *= 4000
write('new_bell.wav', Fs, np.array(sig_synthesis, dtype=np.int16)) 

fig, ax = plt.subplots(2, 1, figsize=(10, 7))
ax[0].plot(x)
ax[0].set_title('Original signal')
ax[1].plot(sig_synthesis)
ax[1].set_title('Synthesized signal')
plt.show()
